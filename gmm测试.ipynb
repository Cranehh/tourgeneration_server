# %%
import numpy as np

# %%
family_gmm = np.load("gmm/family_patterns_demo.npy")
individual_gmm = np.load("gmm/individual_patterns_demo.npy")

# %%
import json
with open("gmm/household_mapping_demo.json", "r") as f:
    household_mapping = json.load(f)

# %%
household_mapping
# Out:
# {'010703000170': 0,
#  '040603000173': 1,
#  '010305000086': 2,
#  '040505000015': 3,
#  '120201000011': 4,
#  '010611000011': 5,
#  '010704000031': 6,
#  '122213000041': 7,
#  '121015000028': 8,
#  '122205000017': 9,
#  '122213000005': 10,
#  '010610000016': 11,
#  '040505000128': 12,
#  '010506000070': 13,
#  '121508000008': 14,
#  '040506000041': 15,
#  '010605000008': 16,
#  '030502000049': 17,
#  '010208000142': 18,
#  '120401000043': 19,
#  '010305000104': 20,
#  '120302000014': 21,
#  '010204000002': 22,
#  '121109000005': 23,
#  '121408000044': 24,
#  '121405000005': 25,
#  '010305000075': 26,
#  '040603000139': 27,
#  '120901000023': 28,
#  '121310000028': 29,
#  '040505000175': 30,
#  '120601000018': 31,
#  '120203000008': 32,
#  '010610000024': 33,
#  '010401000139': 34,
#  '121408000107': 35,
#  '122109000034': 36,
#  '010512000003': 37,
#  '121904000005': 38,
#  '120601000049': 39,
#  '121211000002': 40,
#  '121211000052': 41,
#  '010506000090': 42,
# ...

# %%
family_gmm
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 3.41782931e-33, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 3.32462491e-31, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.65659276e-25, ...,
#         8.10968796e-13, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 5.93568764e-35, ...,
#         5.74557994e-19, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.40229790e-28, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 4.05663407e-55, ...,
#         8.73755733e-35, 0.00000000e+00, 0.00000000e+00]])

# %%
family_gmm.shape
# Out:
# (32738, 118)

# %%
individual_gmm.shape
# Out:
# (32738, 8, 207)

# %%
from family_individual_pattern_extraction_with_progress import (
    ActivityPatternExtractor,
    PatternExtractionConfig,
    load_data_from_notebook
)

# %%
config = PatternExtractionConfig(
        max_family_size=8,
        max_activities=6,
        person_n_components_range=(2, 250),
        household_n_components_range=(2, 125),
        random_state=42
    )
    
extractor = ActivityPatternExtractor(config)

# %%
extractor = extractor.load_model("gmm/activity_pattern_extractor.pkl")
# Out:
# 模型已从 gmm/activity_pattern_extractor.pkl 加载

# %%
extractor.person_gmm.get_cluster_centers()[1]
# Out:
# array([4.00000000e+00, 1.18611228e-01, 2.91817604e-01, 1.19907366e-01,
#        2.90046210e-01, 1.29613823e-03, 5.00000000e-01, 5.00000000e-01,
#        1.59594560e-16, 7.80625564e-18, 6.41847686e-17, 3.29597460e-17,
#        2.63677968e-16, 2.15105711e-16, 6.59194921e-17, 8.67361738e-17,
#        1.00000000e+00, 2.49800181e-16, 1.59594560e-16, 3.46944695e-16,
#        8.60422844e-16, 5.82867088e-16, 2.16840434e-18, 4.51028104e-17,
#        6.24500451e-17, 1.99493200e-17, 5.89805982e-17, 4.85722573e-16,
#        1.24900090e-16])
